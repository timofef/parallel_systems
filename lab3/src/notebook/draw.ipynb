# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300
import numpy as np

# %%
x = [2, 4, 8, 16, 32, 64, 128, 256]

# %%
plt.plot(x, [1.999184, 3.997505, 7.991367, 15.974048, 31.907300, 63.686497, 126.728005, 250.469038], '-', color="black", label="$S_{2}(N), C_{f}=0.5*10^{7}$")
plt.plot(x, [1.921584, 3.765003, 7.220004, 13.763854, 24.796010, 42.887957, 63.881154, 79.794488], '-.',  color="black", label="$S_{2}(N), C_{f}=5*10^{4}$")
plt.xlabel("$N$")
plt.ylabel("$S_{2}(N)$")
plt.grid()
plt.xlim(0)
plt.ylim(0, 260)
plt.plot(x, x, ':',label="$S(N)=N$", color="black")
plt.legend()
plt.show()

# %%
plt.plot(x, [2.007, 3.991, 7.951, 15.661, 31.233, 61.457, 120.911, 229.915], '-', color="black", label="$S(N), C_{f}=0.5*10^{7}$")
plt.plot(x, [1.970, 3.847, 7.403, 14.017, 26.413, 48.445, 85.437, 146.528], '-.',  color="black", label="$S(N), C_{f}=5*10^{4}$")
plt.plot(x, x, ':',  color="black", label="S(N)=N")
plt.xlabel("$N$")
plt.ylabel("$S(N)$")
plt.grid()
plt.xlim(0)
plt.ylim(0, 260)
plt.legend()
plt.show()

# %%
plt.plot(x, [1.996, 3.977, 7.911, 15.689, 31.000, 60.875, 118.538, 227.697], '-', color="black", label="$\~M[S(N)], C_{f}=0.5*10^{7}$")
plt.plot(x, [1.963, 3.824, 7.373, 14.030, 26.207, 47.885, 85.196, 146.475], '-.',  color="black", label="$\~M[S(N)], C_{f}=5*10^{4}$")
plt.xlabel("$N$")
plt.ylabel("$\~M[S(N)]$")
plt.grid()
plt.xlim(0)
plt.ylim(0, 260)
plt.legend()
plt.show()

# %%
plt.plot(x, [0.008, 0.016, 0.041, 0.094, 0.223, 0.542, 1.420, 3.293], '-', color="black", label="$\~\sigma[S(N)], C_{f}=0.5*10^{7}$")
plt.plot(x, [0.007, 0.017, 0.033, 0.073, 0.170, 0.357, 0.676, 1.358], '-.',  color="black", label="$\~\sigma[S(N)], C_{f}=5*10^{4}$")
plt.xlabel("$N$")
plt.ylabel("$\~\sigma[S(N)]$")
plt.grid()
plt.xlim(0)
#plt.ylim(0, 256)
plt.legend()
plt.show()

# %%
n = 16
x = np.linspace(0, 1, n)
y = np.linspace(0, 1, n)

for i in range(n):
    plt.scatter(x, np.full(n, y[i]), marker='.', color="black")
f = 0.5*x
plt.plot(x, f, color="black")
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
#plt.grid()
plt.xlim(0)
#plt.ylim(0, 256)
#plt.legend()
plt.axis('scaled')
plt.show()
